# %% [markdown]
# ### 5. Detect duplicate rows in the dataset.
# ### Remove duplicates and verify the result.

# %%
import pandas as pd

df = pd.read_csv('../student_dataset.csv')

print("identifying duplicate in dataset: ")
print(df.loc[df['Grade'].duplicated(), 'Grade']) # this will not work bcause pandas work rows wise so 

"""it will check like this:
roll,name,grade
101,mandip,a
102,dip,a

here even  if grade has duplication still becasue it check rows wise so there is no duplication

but if we make it only check one column at a time than it will detect duplicate value in whole column 


CONCLUSIION:
DONT DO: print(df[['Roll_no','Name','Grade']].duplicated())
DO: print(df[['Grade']].duplicated())
"""
# Out:
# identifying duplicate in dataset:
# 2    A
# 3    A
# 5    B
# 6    A
# 7    B
# 8    C
# 9    A
# Name: Grade, dtype: object
# "it will check like this:\nroll,name,grade\n101,mandip,a\n102,dip,a\n\nhere even  if grade has duplication still becasue it check rows wise so there is no duplication\n\nbut if we make it only check one column at a time than it will detect duplicate value in whole column \n\n\nCONCLUSIION:\nDONT DO: print(df[['Roll_no','Name','Grade']].duplicated())\nDO: print(df[['Grade']].duplicated())\n"
