# %% [markdown]
# ### 2. Load a CSV file into a DataFrame.
# ### Display column names, data types, and basic statistics.

# %%
import pandas as pd
df = pd.read_csv('../Book1.csv')

print("original dataset: ")
print(df)
print("-"*50)
print(f"data type: {type(df)}")
print("-"*50)
print("basic statistics: ")
print(df.describe())
# Out:
# original dataset:
#       name  age  score
# 0   mandip   22     80
# 1   merina   28     79
# 2  meghana   24     95
# 3  kritika   22     78
# 4  5omisha   21     81
# --------------------------------------------------
# data type: <class 'pandas.core.frame.DataFrame'>
# --------------------------------------------------
# basic statistics:
#              age      score
# count   5.000000   5.000000
# mean   23.400000  82.600000
# std     2.792848   7.021396
# min    21.000000  78.000000
# 25%    22.000000  79.000000
# 50%    22.000000  80.000000
# 75%    24.000000  81.000000
# max    28.000000  95.000000
