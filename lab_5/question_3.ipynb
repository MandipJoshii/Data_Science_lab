# %% [markdown]
# ### 3. Select rows where Marks > 60.
# ### Select only Name and Marks columns.

# %%
import pandas as pd

df = pd.read_csv("../Book1.csv")

print("SELECTING ROWs WITH MARKS GREATER THAN 60: ")
print(df[df['score'] > 60][['name','score']])
# Out:
# SELECTING ROWs WITH MARKS GREATER THAN 60:
#       name  score
# 0   mandip     80
# 1   merina     79
# 2  meghana     95
# 3  kritika     78
# 4   omisha     81
