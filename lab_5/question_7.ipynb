# %% [markdown]
# ### 7. Create a new column by transforming Marks (e.g., Marks / 10).
# ### Rename columns and save the cleaned dataset to a CSV file.

# %%
import pandas as pd

df = pd.read_csv('../Book1.csv')

print("original data: ")
print(df.head())
# Out:
# original data:
#       name  age  score
# 0   mandip   22     80
# 1   merina   28     79
# 2  meghana   24     95
# 3  kritika   22     78
# 4   omisha   21     81

# %% [markdown]
# ### transforming marks

# %%
df['t_marks'] = df['score'] / 10

print(df[['score','t_marks']])
# Out:
#    score  t_marks
# 0     80      8.0
# 1     79      7.9
# 2     95      9.5
# 3     78      7.8
# 4     81      8.1
# 5     56      5.6
# 6     49      4.9
# 7     60      6.0

# %% [markdown]
# ### STORE IN NEW CSV FILE

# %%
new_csv = df['t_marks']
x
new_csv.to_csv('new_data.csv')
